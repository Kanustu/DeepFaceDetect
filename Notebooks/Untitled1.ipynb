# %%
import pickle
import pandas as pd
import numpy as np

# %%
model_list = ['Custom.pkl', 'ResNet.pkl', 'VGG16.pkl', 'Xception.pkl']
for x in range(len(model_list)):
    with open(f'../models/{model_list[x]}', 'rb') as f:
        model_x = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 4
#       2 for x in range(len(model_list)):
#       3     with open(f'../models/{model_list[x]}', 'rb') as f:
# ----> 4         model_x = pickle.load(f)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ava/lib/python3.9/site-packages/keras/__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras import __internal__
#       4 from keras import activations
#       5 from keras import applications
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ava/lib/python3.9/site-packages/keras/__internal__/__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.__internal__ import backend
#       4 from keras.__internal__ import layers
#       5 from keras.__internal__ import losses
#
# ...
